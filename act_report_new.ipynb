# %% [markdown]
# ## Report: act_report

# %% [markdown]
# ### Insights:
#
# > 1. tweets that have the highest retweet counts also have the highest favorite counts(likes): This observation is not far-fetched from the truth that, a positive correlation exists between the favorite_count and retweet_count(this can be proven from the correlation heatmap where the correlation index between retweet_count and favorite_count is 0.9). In this sense, a dog tweet that happens to have a high favorite_count will also have a high retweet_count. This describes the behavior of social media users and can be related to trend culture.
#
# > 2. The ratings are saturated close to the mean rating (1.06) with a standard deviation of 0.219. This shows us that the rating for each tweet is not dispersed from the other. In conclusion, most tweets are rated within a close rating margin: The rating for the various dog tweets saturates around the mean rating(1.06). This tells us that the values have a lower standard deviation and as such, the mean can be used in place of any other rating value(meaning that the mean is a true representation of the whole value set.
#
# > 3. "favorite_count" and "retweet_count" is independent of the dog type, as no particular dog type dominates among the highest_rated retweet and favorites: There is no particular breed of dog that dominates the high rating and retweets. This tells us the rating and retweet is independent of the dog type. and as such, could be dependent on some other factors like the pose of the dog in the picture or some other factor(s).
#
# > 4. The correlation between the "rating" to the "favorite_count" and "retweet_count" is not too strong (0.38) and (0.29) respectively. This tells us that the rating given to any particular dog tweet does not directly affect the favorite and retweet counts of that tweet in a big way, rather, it's a combination of it and some other factors.

# %% [markdown]
# ### Visualization:

# %% [markdown]
# **Bar plot of rating value_counts**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Heatmap of the correlation between variables in the dataframe**
#
# ![image.png](attachment:image.png)
